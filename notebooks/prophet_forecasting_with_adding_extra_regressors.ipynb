# %% [markdown]
# # Import Libraries

# %%
# Load libraries
import numpy as np
from pandas import set_option
set_option('display.max_rows', 500)
set_option('display.max_columns', 500)
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.stats.outliers_influence import variance_inflation_factor
from prophet import Prophet
from datetime import datetime
import pyodbc
from pandas.plotting import scatter_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error,mean_absolute_percentage_error,root_mean_squared_error,r2_score
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Connect to SQL Server

# %%
pyodbc.drivers()
# Out:
# ['SQL Server',
#  'ODBC Driver 17 for SQL Server',
#  'SQL Server Native Client RDA 11.0']

# %%
connection = pyodbc.connect(
"Driver={ODBC Driver 17 for SQL Server};"
"Server=DESKTOP-ROTIMI\SQLEXPRESS;"
"Database=Rossmann;"
"Trusted_Connection=yes;")

# %% [markdown]
# # load dataset

# %% [markdown]
# #### Extracting data from SQL Server

# %%
# View data from SQL Server
train = pd.read_sql("Select * from [dbo].[train_cleaned]",connection)
test = pd.read_sql("Select * from [dbo].[test_cleaned]",connection)

# %% [raw]
# Analyze Data

# %% [markdown]
# # Train Table

# %% [markdown]
# #### View Data

# %%
# head
train.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo  StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1             0
# 1      2          5  2015-07-31   6064        625     1      1             0
# 2      3          5  2015-07-31   8314        821     1      1             0
# 3      5          5  2015-07-31   4822        559     1      1             0
# 4      6          5  2015-07-31   5651        589     1      1             0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
# head
test.head()
# Out:
#    Id  Store  DayOfWeek        Date  Open  Promo  StateHoliday  SchoolHoliday
# 0   1      1          4  2015-09-17     1      1             0              0
# 1   2      3          4  2015-09-17     1      1             0              0
# 2   3      7          4  2015-09-17     1      1             0              0
# 3   4      8          4  2015-09-17     1      1             0              0
# 4   5      9          4  2015-09-17     1      1             0              0

# %% [markdown]
# #### shape of the data

# %%
# shape
print(train.shape)
# Out:
# (814299, 9)

# %%
# shape
print(test.shape)
# Out:
# (41088, 8)

# %% [markdown]
# #### types of the data column

# %%
# types
print(train.dtypes)
# Out:
# Store             int64
# DayOfWeek         int64
# Date             object
# Sales             int64
# Customers         int64
# Open              int64
# Promo             int64
# StateHoliday      int64
# SchoolHoliday     int64
# dtype: object

# %%
# types
print(test.dtypes)
# Out:
# Id                int64
# Store             int64
# DayOfWeek         int64
# Date             object
# Open              int64
# Promo             int64
# StateHoliday      int64
# SchoolHoliday     int64
# dtype: object

# %% [markdown]
# #### data descriptions

# %%
# descriptions
train.describe()
# Out:
#                Store      DayOfWeek          Sales      Customers  \
# count  814299.000000  814299.000000  814299.000000  814299.000000
# mean      557.386423       3.546504    6578.110456     718.145233
# std       323.195128       1.714786    2429.153669     306.621660
# min         1.000000       1.000000       0.000000       0.000000
# 25%       277.000000       2.000000    4798.000000     513.000000
# 50%       557.000000       4.000000    6250.000000     663.000000
# 75%       840.000000       5.000000    8078.000000     861.000000
# max      1115.000000       7.000000   13610.000000    4256.000000
#
#                 Open          Promo   StateHoliday  SchoolHoliday
# count  814299.000000  814299.000000  814299.000000  814299.000000
# mean        0.999000       0.435819       0.000996       0.192362
# std         0.031601       0.495864       0.031543       0.394156
# min         0.000000       0.000000       0.000000       0.000000
# 25%         1.000000       0.000000       0.000000       0.000000
# 50%         1.000000       0.000000       0.000000       0.000000
# 75%         1.000000       1.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000

# %%
# descriptions
test.describe()
# Out:
#                  Id         Store     DayOfWeek          Open         Promo  \
# count  41088.000000  41088.000000  41088.000000  41088.000000  41088.000000
# mean   20544.500000    555.899533      3.979167      0.854361      0.395833
# std    11861.228267    320.274496      2.015481      0.352748      0.489035
# min        1.000000      1.000000      1.000000      0.000000      0.000000
# 25%    10272.750000    279.750000      2.000000      1.000000      0.000000
# 50%    20544.500000    553.500000      4.000000      1.000000      0.000000
# 75%    30816.250000    832.250000      6.000000      1.000000      1.000000
# max    41088.000000   1115.000000      7.000000      1.000000      1.000000
#
#        StateHoliday  SchoolHoliday
# count  41088.000000   41088.000000
# mean       0.004381       0.443487
# std        0.066044       0.496802
# min        0.000000       0.000000
# 25%        0.000000       0.000000
# 50%        0.000000       0.000000
# 75%        0.000000       1.000000
# max        1.000000       1.000000

# %% [markdown]
# #### data descriptions

# %%
# descriptions
train.describe(include = 'object')
# Out:
#               Date
# count       814299
# unique         942
# top     2013-12-24
# freq          1114

# %%
# descriptions
test.describe(include = 'object')
# Out:
#               Date
# count        41088
# unique          48
# top     2015-09-17
# freq           856

# %% [markdown]
# #### Check for missing entries

# %%
# Check for missing entries
total = train.isnull().sum().sort_values(ascending=False)
percent=(train.isnull().sum()*100/len(train)).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1,keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#                Total  Percent
# Store              0      0.0
# DayOfWeek          0      0.0
# Date               0      0.0
# Sales              0      0.0
# Customers          0      0.0
# Open               0      0.0
# Promo              0      0.0
# StateHoliday       0      0.0
# SchoolHoliday      0      0.0

# %%
# Check for missing entries
total = test.isnull().sum().sort_values(ascending=False)
percent=(test.isnull().sum()*100/len(test)).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1,keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#                Total  Percent
# Id                 0      0.0
# Store              0      0.0
# DayOfWeek          0      0.0
# Date               0      0.0
# Open               0      0.0
# Promo              0      0.0
# StateHoliday       0      0.0
# SchoolHoliday      0      0.0

# %% [markdown]
# #### Check for duplicate data

# %%
# locate rows of duplicate data

# calculate duplicates
dups = train.duplicated()
# report if there are any duplicates
print(dups.any())
# Out:
# False

# %%
# locate rows of duplicate data

# calculate duplicates
dups = test.duplicated()
# report if there are any duplicates
print(dups.any())
# Out:
# False

# %%
train.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['Id', 'Store', 'DayOfWeek', 'Date', 'Open', 'Promo', 'StateHoliday',
#        'SchoolHoliday'],
#       dtype='object')

# %%
train.groupby('Open').size()
# Out:
# Open
# 0       814
# 1    813485
# dtype: int64

# %%
test.groupby('Open').size()
# Out:
# Open
# 0     5984
# 1    35104
# dtype: int64

# %%
train.groupby('Promo').size()
# Out:
# Promo
# 0    459412
# 1    354887
# dtype: int64

# %%
test.groupby('Promo').size()
# Out:
# Promo
# 0    24824
# 1    16264
# dtype: int64

# %% [markdown]
# # Forecasting With Facebook Prophet

# %% [markdown]
# ## Forecast With Holiday And Adding Extra Regressors

# %% [markdown]
# #### Rename columns

# %%
# Rename columns for Prophet
train = train.rename(columns={"Date": "ds", "Sales": "y"}).sort_values(by = 'ds')
test = test.rename(columns={"Date": "ds"}).sort_values(by = 'ds')

# %% [markdown]
# #### Convert Date to datetime

# %%
# Convert Date to datetime
train["ds"] = pd.to_datetime(train["ds"])
test["ds"] = pd.to_datetime(test["ds"])

# %%
holiday_dates = train[train["StateHoliday"] == 1]["ds"].unique()

# %%
holidays = pd.DataFrame({"holiday" : "store_holiday",
              "ds" : pd.to_datetime(holiday_dates),
                         "lower_window" : 0,
                         "upper_window" : 1 })

# %% [markdown]
# #### Groupby to fix Duplicate

# %%
# Group by 'Date' and sum sales (fix for duplicate dates)
train = train.groupby("ds", as_index=False).sum()

# %% [markdown]
# #### Data Validation : Splitting

# %%
# Split data: 80% training, 20% validation
validation_size = 0.20
seed = None
train_set,val_set = train_test_split(train,
test_size=validation_size, random_state=seed,shuffle = False)

# %%
train_set.shape,val_set.shape
# Out:
# ((753, 9), (189, 9))

# %% [markdown]
# #### Train Prophet model

# %%
# Train Prophet model
Regressor_model = Prophet(holidays = holidays ,
                     yearly_seasonality=True,
                     weekly_seasonality=True,
                     daily_seasonality=False)
Regressor_model.add_seasonality(name = "monthly",period = 30.5,fourier_order = 5)
Regressor_model.add_regressor("Promo")
Regressor_model.add_regressor("Open")
Regressor_model.fit(train_set[["ds","y","Promo","Open"]])
# Out:
# 12:11:55 - cmdstanpy - INFO - Chain [1] start processing
# 12:11:55 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# #### Predict on validation set

# %%
# Predict on validation set
val_forecast = Regressor_model.predict(val_set[["ds","Promo","Open"]])

# %% [markdown]
# #### Print validation results

# %%
print("Validation Metrics:")
print("MAE :",mean_absolute_error(val_set["y"], val_forecast["yhat"]))
print("MSE :",mean_squared_error(val_set["y"], val_forecast["yhat"]))
print("RMSE :",root_mean_squared_error(val_set["y"], val_forecast["yhat"]))
print("R2 :",r2_score(val_set["y"], val_forecast["yhat"]))
# Out:
# Validation Metrics:
# MAE : 393867.03782813635
# MSE : 276032194575.39594
# RMSE : 525387.6612325378
# R2 : 0.9655709083184318

# %%
# Plot actual vs. predicted sales for validation set
plt.figure(figsize=(12, 6))

# Actual sales
plt.plot(val_set["ds"], val_set["y"], label="Actual Sales", marker='o', linestyle='-')

# Predicted sales
plt.plot(val_set["ds"], val_forecast["yhat"], label="Predicted Sales", marker='x', linestyle='--')

# Labels and title
plt.xlabel("Date")
plt.ylabel("Sales")
plt.title("Actual vs. Predicted Sales (Validation Set)")
plt.legend()
plt.grid()

# Show plot
plt.show()

# %%
# Forecast on test data
# Rename columns for Prophet
test = test.rename(columns={"Date": "ds"})
test_forecast = Regressor_model.predict(test[["ds","Promo","Open"]])

# %%
# Save test forecast results
test_forecast_summary = test_forecast[["ds", "yhat", "yhat_lower", "yhat_upper"]]
test_forecast_summary.rename(columns={"ds": "Date"}, inplace=True)
test_forecast_summary.to_csv("Prophet_forecast_results_Regressors.csv", index=False)
